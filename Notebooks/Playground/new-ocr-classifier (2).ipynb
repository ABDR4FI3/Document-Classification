# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import math
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Modified configuration with 90-10 split
OPTIMIZED_CONFIG = {
    # /content/drive/MyDrive/Colab Notebooks/dataset/
    'data_path': '/kaggle/input/scanned-images-dataset-for-ocr-and-vlm-finetuning/dataset',
    'image_size': (128, 128),
    'batch_size': 64,
    'epochs': 50,
    'initial_learning_rate': 0.0001,
    'num_classes': 10,
    'train_split': 0.9,  # 90% for training
    'weight_decay': 0.0005,
    'dropout_rate': 0.3,
    'early_stopping_patience': 10,
}

def get_file_paths_and_labels(data_path):
    """Get all image paths and their corresponding labels"""
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(data_path))
    
    for class_idx, class_name in enumerate(class_names):
        class_path = os.path.join(data_path, class_name)
        if not os.path.isdir(class_path):
            continue
            
        for img_name in os.listdir(class_path):
            if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_paths.append(os.path.join(class_path, img_name))
                labels.append(class_idx)
    
    return np.array(image_paths), np.array(labels), class_names

def create_data_generators(config):
    """Create separate training and validation generators with fixed splits"""
    
    # Get all file paths and labels
    image_paths, labels, class_names = get_file_paths_and_labels(config['data_path'])
    
    if len(image_paths) == 0:
        raise ValueError("No images found in the data directory")
    
    # Split the data into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(
        image_paths, 
        labels,
        train_size=config['train_split'],
        stratify=labels,
        random_state=42
    )
    
    # Create separate generators for training and validation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        # rotation_range=15,
        # width_shift_range=0.1,
        # height_shift_range=0.1,
        # zoom_range=0.1,
        # horizontal_flip=True,
        fill_mode='nearest'
    )
    
    val_datagen = ImageDataGenerator(
        rescale=1./255  # Only rescaling for validation
    )
    
    def generate_from_paths_and_labels(file_paths, labels, datagen, batch_size, is_training):
        num_samples = len(file_paths)
        num_classes = len(class_names)
        indices = np.arange(num_samples)
        
        while True:
            if is_training:
                np.random.shuffle(indices)
            
            for start in range(0, num_samples, batch_size):
                end = min(start + batch_size, num_samples)
                batch_indices = indices[start:end]
                
                # Initialize batch arrays
                batch_images = np.zeros((len(batch_indices),) + config['image_size'] + (3,))
                batch_labels = np.zeros((len(batch_indices), num_classes))
                
                # Load and preprocess images
                for idx, sample_idx in enumerate(batch_indices):
                    # Load image
                    img_path = file_paths[sample_idx]
                    img = tf.keras.preprocessing.image.load_img(
                        img_path,
                        target_size=config['image_size']
                    )
                    x = tf.keras.preprocessing.image.img_to_array(img)
                    
                    # Apply augmentation if training
                    if is_training:
                        x = train_datagen.random_transform(x)
                    
                    # Rescale
                    x = x / 255.0
                    
                    batch_images[idx] = x
                    batch_labels[idx] = tf.keras.utils.to_categorical(labels[sample_idx], num_classes)
                
                yield batch_images, batch_labels
    
    # Create generators
    train_generator = generate_from_paths_and_labels(
        X_train, y_train, train_datagen, config['batch_size'], is_training=True
    )
    
    validation_generator = generate_from_paths_and_labels(
        X_val, y_val, val_datagen, config['batch_size'], is_training=False
    )
    
    return train_generator, validation_generator, len(X_train), len(X_val), len(class_names)

def create_model(config):
    """Create enhanced CNN model with additional regularization and layers"""
    inputs = layers.Input(shape=(*config['image_size'], 3))
    
    # Initial normalization
    x = layers.experimental.preprocessing.Rescaling(1./255)(inputs)
    
    # First convolution block with regularization
    x = layers.Conv2D(32, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(32, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.25)(x)
    
    # Second convolution block with skip connection
    shortcut = x
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    shortcut = layers.Conv2D(64, (1, 1), padding='same')(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.3)(x)
    
    # Third convolution block with skip connection
    shortcut = x
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    shortcut = layers.Conv2D(128, (1, 1), padding='same')(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.4)(x)
    
    # Fourth convolution block with skip connection
    shortcut = x
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, (3, 3), padding='same', kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    shortcut = layers.Conv2D(256, (1, 1), padding='same')(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(config['dropout_rate'])(x)
    
    # Global pooling and dense layers with heavy regularization
    x = layers.GlobalAveragePooling2D()(x)
    
    # First dense layer with skip connection
    dense_shortcut = layers.Dense(512, kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(dense_shortcut)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(config['dropout_rate'])(x)
    x = layers.Dense(512, kernel_regularizer=tf.keras.regularizers.l2(config['weight_decay']))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([x, dense_shortcut])
    x = layers.Activation('relu')(x)
    x = layers.Dropout(config['dropout_rate'])(x)
    
    # Output layer
    outputs = layers.Dense(config['num_classes'], activation='softmax')(x)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

def main(config):
    """Main training function with improved stability"""
    # Set random seeds
    tf.random.set_seed(42)
    np.random.seed(42)
    
    try:
        # Create data generators with proper splits
        train_generator, validation_generator, train_samples, val_samples, num_classes = create_data_generators(config)
        
        print(f"\nDataset sizes:")
        print(f"Training samples: {train_samples}")
        print(f"Validation samples: {val_samples}")
        print(f"Number of classes: {num_classes}\n")
        
        # Calculate steps
        steps_per_epoch = train_samples // config['batch_size']
        validation_steps = val_samples // config['batch_size']
        
        # Ensure at least one step
        steps_per_epoch = max(1, steps_per_epoch)
        validation_steps = max(1, validation_steps)
        
        # Create and compile model
        model = create_model(config)
        
        optimizer = tf.keras.optimizers.Adam(
            learning_rate=config['initial_learning_rate'],
            clipnorm=1.0
        )
        
        model.compile(
            optimizer=optimizer,
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        # Callbacks
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=config['early_stopping_patience'],
                restore_best_weights=True,
                verbose=1
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=3,
                min_lr=1e-7,
                verbose=1
            ),
            tf.keras.callbacks.ModelCheckpoint(
                filepath='best_model.keras',
                monitor='val_accuracy',
                save_best_only=True,
                mode='max',
                verbose=1
            )
        ]
        
        # Train the model
        print("\nStarting model training...")
        history = model.fit(
            train_generator,
            epochs=config['epochs'],
            steps_per_epoch=steps_per_epoch,
            validation_data=validation_generator,
            validation_steps=validation_steps,
            callbacks=callbacks,
            verbose=1
        )
        
        return model, history
        
    except Exception as e:
        print(f"Error in main function: {str(e)}")
        raise

def plot_training_history(history):
    """Plot training metrics"""
    plt.style.use('seaborn')
    plt.figure(figsize=(15, 5))
    
    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Validation', linewidth=2)
    plt.title('Model Accuracy', fontsize=12)
    plt.xlabel('Epoch', fontsize=10)
    plt.ylabel('Accuracy', fontsize=10)
    plt.legend(fontsize=10)
    plt.grid(True)
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validation', linewidth=2)
    plt.title('Model Loss', fontsize=12)
    plt.xlabel('Epoch', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.legend(fontsize=10)
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    try:
        # Verify data path exists
        if not os.path.exists(OPTIMIZED_CONFIG['data_path']):
            raise ValueError(f"Data path does not exist: {OPTIMIZED_CONFIG['data_path']}")
        
        model, history = main(OPTIMIZED_CONFIG)
        plot_training_history(history)
        
    except Exception as e:
        print(f"Program failed with error: {str(e)}")
# Out:
# Dataset sizes:
# Training samples: 3133
# Validation samples: 349
# Number of classes: 10
#
#
# Starting model training...
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3232 - loss: 2.2670
# Epoch 1: val_accuracy improved from -inf to 0.16563, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 247s 5s/step - accuracy: 0.3249 - loss: 2.2626 - val_accuracy: 0.1656 - val_loss: 2.5197 - learning_rate: 1.0000e-04
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5079 - loss: 1.7335
# Epoch 2: val_accuracy did not improve from 0.16563
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 228s 5s/step - accuracy: 0.5083 - loss: 1.7324 - val_accuracy: 0.1614 - val_loss: 2.6116 - learning_rate: 1.0000e-04
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5642 - loss: 1.5548
# Epoch 3: val_accuracy improved from 0.16563 to 0.18947, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.5642 - loss: 1.5547 - val_accuracy: 0.1895 - val_loss: 2.8125 - learning_rate: 1.0000e-04
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6007 - loss: 1.4600
# Epoch 4: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 4: val_accuracy did not improve from 0.18947
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 226s 5s/step - accuracy: 0.6007 - loss: 1.4600 - val_accuracy: 0.1719 - val_loss: 2.9861 - learning_rate: 1.0000e-04
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6262 - loss: 1.4042
# Epoch 5: val_accuracy did not improve from 0.18947
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6262 - loss: 1.4038 - val_accuracy: 0.1684 - val_loss: 3.0247 - learning_rate: 2.0000e-05
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6316 - loss: 1.3508
# Epoch 6: val_accuracy did not improve from 0.18947
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6319 - loss: 1.3503 - val_accuracy: 0.1789 - val_loss: 2.9894 - learning_rate: 2.0000e-05
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6343 - loss: 1.3573
# Epoch 7: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 7: val_accuracy improved from 0.18947 to 0.20937, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6346 - loss: 1.3564 - val_accuracy: 0.2094 - val_loss: 2.6696 - learning_rate: 2.0000e-05
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6322 - loss: 1.3575
# Epoch 8: val_accuracy improved from 0.20937 to 0.23509, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6324 - loss: 1.3569 - val_accuracy: 0.2351 - val_loss: 2.4325 - learning_rate: 4.0000e-06
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6427 - loss: 1.2868
# Epoch 9: val_accuracy improved from 0.23509 to 0.33684, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6427 - loss: 1.2872 - val_accuracy: 0.3368 - val_loss: 2.1008 - learning_rate: 4.0000e-06
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6507 - loss: 1.2729
# Epoch 10: val_accuracy improved from 0.33684 to 0.42807, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6508 - loss: 1.2730 - val_accuracy: 0.4281 - val_loss: 1.7549 - learning_rate: 4.0000e-06
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6345 - loss: 1.3154
# Epoch 11: val_accuracy improved from 0.42807 to 0.49825, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6346 - loss: 1.3153 - val_accuracy: 0.4982 - val_loss: 1.5721 - learning_rate: 4.0000e-06
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6568 - loss: 1.2817
# Epoch 12: val_accuracy improved from 0.49825 to 0.58246, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6567 - loss: 1.2818 - val_accuracy: 0.5825 - val_loss: 1.4467 - learning_rate: 4.0000e-06
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6719 - loss: 1.2564
# Epoch 13: val_accuracy improved from 0.58246 to 0.61563, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6717 - loss: 1.2569 - val_accuracy: 0.6156 - val_loss: 1.3823 - learning_rate: 4.0000e-06
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6614 - loss: 1.2692
# Epoch 14: val_accuracy improved from 0.61563 to 0.63509, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6613 - loss: 1.2694 - val_accuracy: 0.6351 - val_loss: 1.3423 - learning_rate: 4.0000e-06
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6709 - loss: 1.2297
# Epoch 15: val_accuracy did not improve from 0.63509
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6709 - loss: 1.2300 - val_accuracy: 0.6246 - val_loss: 1.3593 - learning_rate: 4.0000e-06
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6575 - loss: 1.2947
# Epoch 16: val_accuracy did not improve from 0.63509
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6576 - loss: 1.2942 - val_accuracy: 0.6316 - val_loss: 1.3161 - learning_rate: 4.0000e-06
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6593 - loss: 1.2783
# Epoch 17: val_accuracy improved from 0.63509 to 0.65263, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6594 - loss: 1.2780 - val_accuracy: 0.6526 - val_loss: 1.2791 - learning_rate: 4.0000e-06
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6531 - loss: 1.2676
# Epoch 18: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6531 - loss: 1.2679 - val_accuracy: 0.6421 - val_loss: 1.2786 - learning_rate: 4.0000e-06
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6754 - loss: 1.2518
# Epoch 19: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6752 - loss: 1.2517 - val_accuracy: 0.6375 - val_loss: 1.2890 - learning_rate: 4.0000e-06
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6555 - loss: 1.2774
# Epoch 20: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.6556 - loss: 1.2772 - val_accuracy: 0.6491 - val_loss: 1.2904 - learning_rate: 4.0000e-06
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6549 - loss: 1.2527
# Epoch 21: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 21: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6550 - loss: 1.2528 - val_accuracy: 0.6246 - val_loss: 1.3225 - learning_rate: 4.0000e-06
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6532 - loss: 1.2620
# Epoch 22: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6531 - loss: 1.2621 - val_accuracy: 0.6421 - val_loss: 1.2950 - learning_rate: 8.0000e-07
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6839 - loss: 1.2083
# Epoch 23: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.6837 - loss: 1.2089 - val_accuracy: 0.6491 - val_loss: 1.2590 - learning_rate: 8.0000e-07
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6792 - loss: 1.2246
# Epoch 24: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6789 - loss: 1.2250 - val_accuracy: 0.6456 - val_loss: 1.2647 - learning_rate: 8.0000e-07
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6610 - loss: 1.2534
# Epoch 25: val_accuracy did not improve from 0.65263
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6611 - loss: 1.2532 - val_accuracy: 0.6438 - val_loss: 1.2744 - learning_rate: 8.0000e-07
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6643 - loss: 1.2500
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 26: val_accuracy improved from 0.65263 to 0.65965, saving model to best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6644 - loss: 1.2500 - val_accuracy: 0.6596 - val_loss: 1.2799 - learning_rate: 8.0000e-07
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6637 - loss: 1.2643
# Epoch 27: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.6640 - loss: 1.2637 - val_accuracy: 0.6316 - val_loss: 1.3153 - learning_rate: 1.6000e-07
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6597 - loss: 1.2819
# Epoch 28: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6598 - loss: 1.2815 - val_accuracy: 0.6386 - val_loss: 1.2917 - learning_rate: 1.6000e-07
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6673 - loss: 1.2541
# Epoch 29: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6673 - loss: 1.2539 - val_accuracy: 0.6456 - val_loss: 1.2561 - learning_rate: 1.6000e-07
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6695 - loss: 1.2266
# Epoch 30: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.6695 - loss: 1.2270 - val_accuracy: 0.6386 - val_loss: 1.2601 - learning_rate: 1.6000e-07
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6785 - loss: 1.2466
# Epoch 31: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 223s 5s/step - accuracy: 0.6784 - loss: 1.2465 - val_accuracy: 0.6438 - val_loss: 1.2725 - learning_rate: 1.6000e-07
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6661 - loss: 1.2543
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 32: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6660 - loss: 1.2542 - val_accuracy: 0.6561 - val_loss: 1.2776 - learning_rate: 1.6000e-07
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6656 - loss: 1.2524
# Epoch 33: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6658 - loss: 1.2523 - val_accuracy: 0.6281 - val_loss: 1.3150 - learning_rate: 1.0000e-07
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6730 - loss: 1.2379
# Epoch 34: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6731 - loss: 1.2378 - val_accuracy: 0.6386 - val_loss: 1.2914 - learning_rate: 1.0000e-07
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6843 - loss: 1.2223
# Epoch 35: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6839 - loss: 1.2231 - val_accuracy: 0.6526 - val_loss: 1.2546 - learning_rate: 1.0000e-07
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6700 - loss: 1.2241
# Epoch 36: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6699 - loss: 1.2244 - val_accuracy: 0.6386 - val_loss: 1.2591 - learning_rate: 1.0000e-07
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6689 - loss: 1.2410
# Epoch 37: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6690 - loss: 1.2409 - val_accuracy: 0.6469 - val_loss: 1.2714 - learning_rate: 1.0000e-07
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6863 - loss: 1.2135
# Epoch 38: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6859 - loss: 1.2140 - val_accuracy: 0.6561 - val_loss: 1.2764 - learning_rate: 1.0000e-07
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6705 - loss: 1.2374
# Epoch 39: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6704 - loss: 1.2378 - val_accuracy: 0.6281 - val_loss: 1.3140 - learning_rate: 1.0000e-07
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6605 - loss: 1.2540
# Epoch 40: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6606 - loss: 1.2537 - val_accuracy: 0.6421 - val_loss: 1.2901 - learning_rate: 1.0000e-07
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6678 - loss: 1.2395
# Epoch 41: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6679 - loss: 1.2396 - val_accuracy: 0.6526 - val_loss: 1.2540 - learning_rate: 1.0000e-07
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6689 - loss: 1.2270
# Epoch 42: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6688 - loss: 1.2273 - val_accuracy: 0.6421 - val_loss: 1.2590 - learning_rate: 1.0000e-07
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6691 - loss: 1.2371
# Epoch 43: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 225s 5s/step - accuracy: 0.6692 - loss: 1.2373 - val_accuracy: 0.6469 - val_loss: 1.2712 - learning_rate: 1.0000e-07
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6747 - loss: 1.2448
# Epoch 44: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6746 - loss: 1.2451 - val_accuracy: 0.6561 - val_loss: 1.2768 - learning_rate: 1.0000e-07
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6693 - loss: 1.2367
# Epoch 45: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6692 - loss: 1.2368 - val_accuracy: 0.6281 - val_loss: 1.3134 - learning_rate: 1.0000e-07
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6846 - loss: 1.2157
# Epoch 46: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6845 - loss: 1.2160 - val_accuracy: 0.6421 - val_loss: 1.2900 - learning_rate: 1.0000e-07
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6850 - loss: 1.2391
# Epoch 47: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6848 - loss: 1.2391 - val_accuracy: 0.6526 - val_loss: 1.2540 - learning_rate: 1.0000e-07
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6639 - loss: 1.2510
# Epoch 48: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6641 - loss: 1.2506 - val_accuracy: 0.6421 - val_loss: 1.2588 - learning_rate: 1.0000e-07
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6702 - loss: 1.2348
# Epoch 49: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 226s 5s/step - accuracy: 0.6701 - loss: 1.2352 - val_accuracy: 0.6469 - val_loss: 1.2712 - learning_rate: 1.0000e-07
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6602 - loss: 1.2624
# Epoch 50: val_accuracy did not improve from 0.65965
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 224s 5s/step - accuracy: 0.6602 - loss: 1.2623 - val_accuracy: 0.6561 - val_loss: 1.2762 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 41.
# <ipython-input-1-b8f76c9300c6>:252: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
